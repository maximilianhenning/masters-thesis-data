# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
people_df = pd.read_csv("../output/persons.csv", sep = ";", encoding = "utf8")
jobs_df = pd.read_csv("../output/jobs.csv", sep = ";", encoding = "utf8")
voyages_df = pd.read_csv("../output/voyages.csv", sep = ";", encoding = "utf8")
ships_df = pd.read_csv("../output/ships.csv", sep = ";", encoding = "utf8")

# %% [markdown]
# Add a list of ranks ordered according to EIC pay grades

# %%
ranks_ordered_list = [
    "apprentice", "purser", "seaman", 
    "capt's servant", "quarter master", "midshipman", "coxswain",
    "lieutenant", "boatswain", "6th mate", "5th mate", 
    "4th mate", "surgeon's mate", "surgeon",
    "3rd mate", "2nd mate", "1st mate", 
    "master", "capt", "passenger"
]

# %% [markdown]
# Categorise ranks

# %%
rank_category_dict = {
"before_mast": ["apprentice", "purser", "seaman"],
"middle": ["capt's servant", "quarter master", "midshipman", "coxswain", "lieutenant", "boatswain"],
"low_mates": ["6th mate", "5th mate", "4th mate", "surgeon's mate", "surgeon"],
"high_mates": ["3rd mate", "2nd mate", "1st mate"],
"master_capt": ["master", "capt", "passenger"]
}

# %% [markdown]
# ## Initial exploration

# %% [markdown]
# How many jobs are there?

# %%
len(jobs_df.index)
# Out:
# 42834

# %% [markdown]
# How much of that does each rank take up?

# %%
job_percentages_df = pd.DataFrame(jobs_df.value_counts("rank"))
job_percentages_df = job_percentages_df.reset_index().rename(columns = {0: "count"})
job_percentages_df["percentage"] = job_percentages_df["count"] / job_percentages_df["count"].sum()
job_percentages_df
# Out:
#               rank  count  percentage
# 0             capt   5585    0.130387
# 1          surgeon   4872    0.113741
# 2         2nd mate   4756    0.111033
# 3         1st mate   4596    0.107298
# 4         3rd mate   4030    0.094084
# 5           purser   3928    0.091703
# 6         4th mate   3806    0.088855
# 7       midshipman   3292    0.076855
# 8         5th mate   2927    0.068334
# 9         6th mate   1726    0.040295
# 10          seaman   1686    0.039361
# 11          master    455    0.010622
# 12      apprentice    338    0.007891
# 13  capt's servant    281    0.006560
# 14  surgeon's mate    212    0.004949
# 15      lieutenant    189    0.004412
# 16       passenger    123    0.002872
# 17       boatswain     15    0.000350
# 18  quarter master     13    0.000303
# 19        coxswain      4    0.000093

# %% [markdown]
# What's the average crew size per voyage?

# %%
voyages_ships_df = pd.merge(voyages_df, ships_df,
                           how = "left",
                           on = "ship_id")
voyages_ships_df = voyages_ships_df.loc[voyages_ships_df["crew"].notna()]
voyages_ships_df["crew"].mean(), 1 / voyages_ships_df["crew"].mean()
# Out:
# (87.19080174021131, 0.01146909972200442)

# %% [markdown]
# ## Careers

# %% [markdown]
# How did employees start and end their careers? Since we are interested in career progression, we filter out those careers that only have a single job.

# %%
people_with_jobs = list(set(jobs_df["person_id"].tolist()))
first_rank_dict = {}
for rank in ranks_ordered_list:
    first_rank_dict[rank] = 0
for person in people_with_jobs:
    rank_list = jobs_df.loc[jobs_df["person_id"] == person]["rank"].tolist()
    if len(rank_list) > 1:
        first_rank = rank_list[0]
        first_rank_dict[first_rank] += 1
first_rank_df = pd.DataFrame.from_dict(first_rank_dict, orient = "index")
first_rank_df = first_rank_df.reset_index().rename(columns = {"index": "rank", 0: "count"})
first_rank_df = first_rank_df.sort_values(by = "count", ascending = False)

# %% [markdown]
# What are the percentages of ranks in the first ranks of careers?

# %%
first_rank_df["percentage"] = first_rank_df["count"] / first_rank_df["count"].sum()
first_rank_df.head()
# Out:
#           rank  count  percentage
# 5   midshipman   1037    0.170784
# 13     surgeon    737    0.121377
# 2       seaman    676    0.111331
# 1       purser    599    0.098650
# 10    5th mate    532    0.087615

# %%
last_rank_dict = {}
for rank in ranks_ordered_list:
    last_rank_dict[rank] = 0
for person in people_with_jobs:
    rank_list = jobs_df.loc[jobs_df["person_id"] == person]["rank"].tolist()
    if len(rank_list) > 1:
        last_rank = rank_list[-1]
        last_rank_dict[last_rank] += 1
last_rank_df = pd.DataFrame.from_dict(last_rank_dict, orient = "index")
last_rank_df = last_rank_df.reset_index().rename(columns = {"index": "rank", 0: "count"})
last_rank_df = last_rank_df.sort_values(by = "count", ascending = False)

# %% [markdown]
# What are the percentages of ranks in the last ranks of careers?

# %%
last_rank_df["percentage"] = last_rank_df["count"] / last_rank_df["count"].sum()
last_rank_df.head()
# Out:
#         rank  count  percentage
# 18      capt   1274    0.209816
# 16  1st mate    911    0.150033
# 13   surgeon    880    0.144928
# 15  2nd mate    848    0.139657
# 14  3rd mate    640    0.105402

# %% [markdown]
# Let's plot how people moved from a first to a last job.

# %%
rank_id_dict = {}
counter = 1
for rank in ranks_ordered_list:
    rank_id_dict[rank] = counter
    counter += 1
with open("./jobs/nodes.csv", "w") as file:
    file.write("ID;label;category;count\n")
    for category in rank_category_dict:
        for rank in rank_category_dict[category]:
            count = str(len(jobs_df.loc[jobs_df["rank"] == rank].index))
            file.write(str(rank_id_dict[rank]) + ";" + rank + ";" + category + ";" + count + "\n")

# %%
first_last_rank_dict = {}
for first_rank in ranks_ordered_list:
    first_last_rank_dict[first_rank] = {}
    for last_rank in ranks_ordered_list:
        first_last_rank_dict[first_rank][last_rank] = 0
for person in people_with_jobs:
    rank_list = jobs_df.loc[jobs_df["person_id"] == person]["rank"].tolist()
    if len(rank_list) > 1:
        first_rank = rank_list[0]
        last_rank = rank_list[-1]
        first_last_rank_dict[first_rank][last_rank] += 1
with open("./jobs/first_last_edges.csv", "w") as file:
    file.write("Source;Target;Weight;Direction\n")
    for first_rank in first_last_rank_dict:
        for last_rank in first_last_rank_dict[first_rank]:
            if not first_last_rank_dict[first_rank][last_rank] == 0:
                first_rank_id = rank_id_dict[first_rank]
                last_rank_id = rank_id_dict[last_rank]
                file.write(str(first_rank_id) + ";" + str(last_rank_id) + ";" + str(first_last_rank_dict[first_rank][last_rank]) + ";")
                if last_rank_id > first_rank_id:
                    file.write("promotion\n")
                elif last_rank_id == first_rank_id:
                    file.write("unchanged\n")
                else:
                    file.write("demotion\n")
first_last_rank_df = pd.DataFrame.from_dict(first_last_rank_dict, orient = "index")

# %%
def get_od_matrix(df, name):
    styled_df = df.style.background_gradient(cmap = "viridis", axis = 1)
    styled_df = styled_df.set_table_styles([
        {'selector': 'table', 'props': [('font-family', 'Helvetica')]},
        {'selector': 'td.data', 'props': [('font-family', 'Helvetica'), ('border', 'none')],},
        {'selector': 'th.col_heading', 'props': [('font-family', 'Helvetica')]},
        {'selector': 'th.row_heading', 'props': [('font-family', 'Helvetica')]}
    ])
    with open("jobs/" + name + ".html", "w") as file:
        file.write(styled_df.render())
    return styled_df
first_last_rank_styled_df = get_od_matrix(first_last_rank_df, "first_last_job")
first_last_rank_styled_df
# Out:
# C:\Users\lorga\AppData\Local\Temp\ipykernel_7272\2787265348.py:10: FutureWarning: this method is deprecated in favour of `Styler.to_html()`
#   file.write(styled_df.render())
# <style type="text/css">
# #T_33c16 table {
#   font-family: Helvetica;
# }
# #T_33c16 td.data {
#   font-family: Helvetica;
#   border: none;
# }
# #T_33c16 th.col_heading {
#   font-family: Helvetica;
# }
# #T_33c16 th.row_heading {
#   font-family: Helvetica;
# }
# #T_33c16_row0_col0, #T_33c16_row0_col2, #T_33c16_row0_col3, #T_33c16_row0_col4, #T_33c16_row0_col6, #T_33c16_row0_col8, #T_33c16_row0_col12, #T_33c16_row0_col19, #T_33c16_row1_col0, #T_33c16_row1_col2, #T_33c16_row1_col3, #T_33c16_row1_col4, #T_33c16_row1_col5, #T_33c16_row1_col6, #T_33c16_row1_col7, #T_33c16_row1_col8, #T_33c16_row1_col12, #T_33c16_row1_col19, #T_33c16_row2_col3, #T_33c16_row2_col4, #T_33c16_row2_col6, #T_33c16_row2_col8, #T_33c16_row2_col12, #T_33c16_row2_col19, #T_33c16_row3_col0, #T_33c16_row3_col2, #T_33c16_row3_col3, #T_33c16_row3_col4, #T_33c16_row3_col5, #T_33c16_row3_col6, #T_33c16_row3_col7, #T_33c16_row3_col8, #T_33c16_row3_col10, #T_33c16_row3_col12, #T_33c16_row3_col13, #T_33c16_row3_col17, #T_33c16_row3_col19, #T_33c16_row4_col0, #T_33c16_row4_col1, #T_33c16_row4_col2, #T_33c16_row4_col3, #T_33c16_row4_col4, #T_33c16_row4_col5, #T_33c16_row4_col6, #T_33c16_row4_col7, #T_33c16_row4_col8, #T_33c16_row4_col9, #T_33c16_row4_col10, #T_33c16_row4_col11, #T_33c16_row4_col12, #T_33c16_row4_col13, #T_33c16_row4_col14, #T_33c16_row4_col15, #T_33c16_row4_col17, #T_33c16_row4_col19, #T_33c16_row5_col0, #T_33c16_row5_col3, #T_33c16_row5_col4, #T_33c16_row5_col6, #T_33c16_row5_col8, #T_33c16_row5_col12, #T_33c16_row5_col19, #T_33c16_row6_col0, #T_33c16_row6_col1, #T_33c16_row6_col2, #T_33c16_row6_col3, #T_33c16_row6_col4, #T_33c16_row6_col5, #T_33c16_row6_col6, #T_33c16_row6_col7, #T_33c16_row6_col8, #T_33c16_row6_col9, #T_33c16_row6_col10, #T_33c16_row6_col11, #T_33c16_row6_col12, #T_33c16_row6_col13, #T_33c16_row6_col14, #T_33c16_row6_col15, #T_33c16_row6_col16, #T_33c16_row6_col17, #T_33c16_row6_col18, #T_33c16_row6_col19, #T_33c16_row7_col0, #T_33c16_row7_col1, #T_33c16_row7_col2, #T_33c16_row7_col3, #T_33c16_row7_col4, #T_33c16_row7_col5, #T_33c16_row7_col6, #T_33c16_row7_col7, #T_33c16_row7_col8, #T_33c16_row7_col9, #T_33c16_row7_col10, #T_33c16_row7_col12, #T_33c16_row7_col17, #T_33c16_row7_col18, #T_33c16_row7_col19, #T_33c16_row8_col0, #T_33c16_row8_col1, #T_33c16_row8_col2, #T_33c16_row8_col3, #T_33c16_row8_col4, #T_33c16_row8_col5, #T_33c16_row8_col6, #T_33c16_row8_col7, #T_33c16_row8_col8, #T_33c16_row8_col9, #T_33c16_row8_col10, #T_33c16_row8_col11, #T_33c16_row8_col12, #T_33c16_row8_col13, #T_33c16_row8_col14, #T_33c16_row8_col15, #T_33c16_row8_col16, #T_33c16_row8_col17, #T_33c16_row8_col18, #T_33c16_row8_col19, #T_33c16_row9_col0, #T_33c16_row9_col2, #T_33c16_row9_col3, #T_33c16_row9_col4, #T_33c16_row9_col6, #T_33c16_row9_col7, #T_33c16_row9_col8, #T_33c16_row9_col12, #T_33c16_row9_col17, #T_33c16_row9_col19, #T_33c16_row10_col0, #T_33c16_row10_col2, #T_33c16_row10_col3, #T_33c16_row10_col4, #T_33c16_row10_col5, #T_33c16_row10_col6, #T_33c16_row10_col7, #T_33c16_row10_col8, #T_33c16_row10_col12, #T_33c16_row10_col19, #T_33c16_row11_col0, #T_33c16_row11_col2, #T_33c16_row11_col3, #T_33c16_row11_col4, #T_33c16_row11_col5, #T_33c16_row11_col6, #T_33c16_row11_col7, #T_33c16_row11_col8, #T_33c16_row11_col12, #T_33c16_row11_col17, #T_33c16_row11_col19, #T_33c16_row12_col0, #T_33c16_row12_col1, #T_33c16_row12_col2, #T_33c16_row12_col3, #T_33c16_row12_col4, #T_33c16_row12_col5, #T_33c16_row12_col6, #T_33c16_row12_col8, #T_33c16_row12_col9, #T_33c16_row12_col10, #T_33c16_row12_col11, #T_33c16_row12_col14, #T_33c16_row12_col15, #T_33c16_row12_col16, #T_33c16_row12_col17, #T_33c16_row12_col18, #T_33c16_row12_col19, #T_33c16_row13_col0, #T_33c16_row13_col1, #T_33c16_row13_col2, #T_33c16_row13_col3, #T_33c16_row13_col4, #T_33c16_row13_col5, #T_33c16_row13_col6, #T_33c16_row13_col7, #T_33c16_row13_col8, #T_33c16_row13_col9, #T_33c16_row13_col10, #T_33c16_row13_col14, #T_33c16_row13_col17, #T_33c16_row13_col19, #T_33c16_row14_col0, #T_33c16_row14_col2, #T_33c16_row14_col3, #T_33c16_row14_col4, #T_33c16_row14_col5, #T_33c16_row14_col6, #T_33c16_row14_col7, #T_33c16_row14_col8, #T_33c16_row14_col12, #T_33c16_row14_col17, #T_33c16_row14_col19, #T_33c16_row15_col0, #T_33c16_row15_col2, #T_33c16_row15_col3, #T_33 ...
#   background-color: #440154;
#   color: #f1f1f1;
# }
# #T_33c16_row0_col1, #T_33c16_row0_col5, #T_33c16_row0_col9, #T_33c16_row1_col10, #T_33c16_row1_col15, #T_33c16_row3_col1, #T_33c16_row5_col17, #T_33c16_row10_col17, #T_33c16_row15_col11, #T_33c16_row18_col16 {
#   background-color: #46085c;
#   color: #f1f1f1;
# }
# #T_33c16_row0_col7, #T_33c16_row0_col10, #T_33c16_row0_col13, #T_33c16_row0_col17, #T_33c16_row2_col10, #T_33c16_row3_col9, #T_33c16_row10_col9, #T_33c16_row11_col13 {
#   background-color: #471063;
#   color: #f1f1f1;
# }
# #T_33c16_row0_col11 {
#   background-color: #22a785;
#   color: #f1f1f1;
# }
# #T_33c16_row0_col14 {
#   background-color: #aadc32;
#   color: #000000;
# }
# #T_33c16_row0_col15 {
#   background-color: #73d056;
#   color: #000000;
# }
# #T_33c16_row0_col16, #T_33c16_row10_col18 {
#   background-color: #e5e419;
#   color: #000000;
# }
# #T_33c16_row0_col18, #T_33c16_row1_col1, #T_33c16_row2_col18, #T_33c16_row3_col18, #T_33c16_row4_col16, #T_33c16_row4_col18, #T_33c16_row5_col15, #T_33c16_row7_col11, #T_33c16_row7_col15, #T_33c16_row9_col11, #T_33c16_row10_col15, #T_33c16_row11_col15, #T_33c16_row12_col13, #T_33c16_row13_col13, #T_33c16_row14_col16, #T_33c16_row15_col16, #T_33c16_row16_col16, #T_33c16_row17_col17, #T_33c16_row18_col18, #T_33c16_row19_col10, #T_33c16_row19_col14, #T_33c16_row19_col15, #T_33c16_row19_col16 {
#   background-color: #fde725;
#   color: #000000;
# }
# #T_33c16_row1_col9, #T_33c16_row1_col16, #T_33c16_row2_col2, #T_33c16_row2_col13, #T_33c16_row5_col7, #T_33c16_row12_col7, #T_33c16_row13_col18, #T_33c16_row14_col9, #T_33c16_row15_col7, #T_33c16_row15_col9, #T_33c16_row15_col10 {
#   background-color: #450457;
#   color: #f1f1f1;
# }
# #T_33c16_row1_col11, #T_33c16_row9_col5, #T_33c16_row11_col9 {
#   background-color: #46075a;
#   color: #f1f1f1;
# }
# #T_33c16_row1_col13, #T_33c16_row1_col14, #T_33c16_row2_col9, #T_33c16_row10_col13, #T_33c16_row12_col12, #T_33c16_row14_col10, #T_33c16_row17_col14 {
#   background-color: #460b5e;
#   color: #f1f1f1;
# }
# #T_33c16_row1_col17, #T_33c16_row2_col0, #T_33c16_row2_col7, #T_33c16_row2_col17, #T_33c16_row5_col2, #T_33c16_row13_col11, #T_33c16_row13_col12, #T_33c16_row13_col15, #T_33c16_row13_col16, #T_33c16_row18_col9, #T_33c16_row18_col11 {
#   background-color: #440256;
#   color: #f1f1f1;
# }
# #T_33c16_row1_col18, #T_33c16_row5_col5 {
#   background-color: #481d6f;
#   color: #f1f1f1;
# }
# #T_33c16_row2_col1, #T_33c16_row2_col5 {
#   background-color: #470d60;
#   color: #f1f1f1;
# }
# #T_33c16_

# %% [markdown]
# Only the ones with more data

# %%
first_last_rank_detail_df = first_last_rank_df.drop(columns = {"purser", "surgeon's mate", "surgeon", "master", "passenger", "boatswain", "coxswain", "lieutenant", "quarter master"},
                                          index = {"purser", "surgeon's mate", "surgeon", "master", "passenger", "boatswain", "coxswain", "lieutenant", "quarter master"})
first_last_rank_detail_styled_df = get_od_matrix(first_last_rank_detail_df, "first_last_job_detail")
first_last_rank_detail_styled_df
# Out:
# C:\Users\lorga\AppData\Local\Temp\ipykernel_7272\2787265348.py:10: FutureWarning: this method is deprecated in favour of `Styler.to_html()`
#   file.write(styled_df.render())
# <style type="text/css">
# #T_23acc table {
#   font-family: Helvetica;
# }
# #T_23acc td.data {
#   font-family: Helvetica;
#   border: none;
# }
# #T_23acc th.col_heading {
#   font-family: Helvetica;
# }
# #T_23acc th.row_heading {
#   font-family: Helvetica;
# }
# #T_23acc_row0_col0, #T_23acc_row0_col1, #T_23acc_row0_col2, #T_23acc_row1_col2, #T_23acc_row2_col0, #T_23acc_row2_col1, #T_23acc_row2_col2, #T_23acc_row2_col3, #T_23acc_row2_col5, #T_23acc_row3_col0, #T_23acc_row3_col2, #T_23acc_row4_col0, #T_23acc_row4_col1, #T_23acc_row4_col2, #T_23acc_row5_col0, #T_23acc_row5_col1, #T_23acc_row5_col2, #T_23acc_row5_col3, #T_23acc_row6_col0, #T_23acc_row6_col1, #T_23acc_row6_col2, #T_23acc_row6_col3, #T_23acc_row7_col0, #T_23acc_row7_col1, #T_23acc_row7_col2, #T_23acc_row7_col3, #T_23acc_row8_col0, #T_23acc_row8_col1, #T_23acc_row8_col2, #T_23acc_row8_col3, #T_23acc_row9_col0, #T_23acc_row9_col1, #T_23acc_row9_col2, #T_23acc_row9_col3, #T_23acc_row9_col5, #T_23acc_row10_col0, #T_23acc_row10_col1, #T_23acc_row10_col2, #T_23acc_row10_col3, #T_23acc_row10_col5, #T_23acc_row10_col7 {
#   background-color: #440154;
#   color: #f1f1f1;
# }
# #T_23acc_row0_col3, #T_23acc_row0_col4, #T_23acc_row8_col6, #T_23acc_row10_col9 {
#   background-color: #46085c;
#   color: #f1f1f1;
# }
# #T_23acc_row0_col5, #T_23acc_row1_col5, #T_23acc_row2_col4, #T_23acc_row5_col4 {
#   background-color: #471063;
#   color: #f1f1f1;
# }
# #T_23acc_row0_col6 {
#   background-color: #22a785;
#   color: #f1f1f1;
# }
# #T_23acc_row0_col7 {
#   background-color: #aadc32;
#   color: #000000;
# }
# #T_23acc_row0_col8 {
#   background-color: #73d056;
#   color: #000000;
# }
# #T_23acc_row0_col9, #T_23acc_row5_col10 {
#   background-color: #e5e419;
#   color: #000000;
# }
# #T_23acc_row0_col10, #T_23acc_row1_col10, #T_23acc_row2_col10, #T_23acc_row3_col8, #T_23acc_row4_col6, #T_23acc_row5_col8, #T_23acc_row6_col8, #T_23acc_row7_col9, #T_23acc_row8_col9, #T_23acc_row9_col9, #T_23acc_row10_col10 {
#   background-color: #fde725;
#   color: #000000;
# }
# #T_23acc_row1_col0, #T_23acc_row3_col1, #T_23acc_row10_col4, #T_23acc_row10_col6 {
#   background-color: #440256;
#   color: #f1f1f1;
# }
# #T_23acc_row1_col1, #T_23acc_row7_col4, #T_23acc_row8_col4, #T_23acc_row8_col5 {
#   background-color: #450457;
#   color: #f1f1f1;
# }
# #T_23acc_row1_col3 {
#   background-color: #470d60;
#   color: #f1f1f1;
# }
# #T_23acc_row1_col4, #T_23acc_row7_col5 {
#   background-color: #460b5e;
#   color: #f1f1f1;
# }
# #T_23acc_row1_col6 {
#   background-color: #26ad81;
#   color: #f1f1f1;
# }
# #T_23acc_row1_col7 {
#   background-color: #28ae80;
#   color: #f1f1f1;
# }
# #T_23acc_row1_col8 {
#   background-color: #4ac16d;
#   color: #000000;
# }
# #T_23acc_row1_col9 {
#   background-color: #5cc863;
#   color: #000000;
# }
# #T_23acc_row2_col6 {
#   background-color: #1fa287;
#   color: #f1f1f1;
# }
# #T_23acc_row2_col7 {
#   background-color: #25ac82;
#   color: #f1f1f1;
# }
# #T_23acc_row2_col8 {
#   background-color: #44bf70;
#   color: #f1f1f1;
# }
# #T_23acc_row2_col9 {
#   background-color: #3bbb75;
#   color: #f1f1f1;
# }
# #T_23acc_row3_col3 {
#   background-color: #481d6f;
#   color: #f1f1f1;
# }
# #T_23acc_row3_col4 {
#   background-color: #472c7a;
#   color: #f1f1f1;
# }
# #T_23acc_row3_col5 {
#   background-color: #424186;
#   color: #f1f1f1;
# }
# #T_23acc_row3_col6 {
#   background-color: #9dd93b;
#   color: #000000;
# }
# #T_23acc_row3_col7 {
#   background-color: #46c06f;
#   color: #f1f1f1;
# }
# #T_23acc_row3_col9 {
#   background-color: #dde318;
#   color: #000000;
# }
# #T_23acc_row3_col10, #T_23acc_row8_col10 {
#   background-color: #f8e621;
#   color: #000000;
# }
# #T_23acc_row4_col3, #T_23acc_row6_col4 {
#   background-color: #46075a;
#   color: #f1f1f1;
# }
# #T_23acc_row4_col4 {
#   background-color: #26828e;
#   color: #f1f1f1;
# }
# #T_23acc_row4_col5, #T_23acc_row9_col10 {
#   background-color: #a5db36;
#   color: #000000;
# }
# #T_23acc_row4_col7 {
#   background-color: #6ece58;
#   color: #000000;
# }
# #T_23acc_row4_col8 {
#   background-color: #8ed645;
#   color: #000000;
# }
# #T_23acc_row4_col9 {
#   background-color: #5ac864;
#   color: #000000;
# }
# #T_23acc_row4_col10 {
#   background-color: #65cb5e;
#   color: #000000;
# }
# #T_23acc_row5_col5 {
#   background-color: #25ab82;
#   color: #f1f1f1;
# }
# #T_23acc_row5_col6, #T_23acc_row5_col7 {
#   background-color: #a2da37;
#   color: #000000;
# }
# #T_23acc_row5_col9 {
#   background-color: #7ad151;
#   color: #000000;
# }
# #T_23acc_row6_col5 {
#   background-color: #482173;
#   color: #f1f1f1;
# }
# #T_23acc_row6_col6 {
#   background-color: #23888e;
#   color: #f1f1f1;
# }
# #T_23acc_row6_col7 {
#   background-color: #bddf26;
#   color: #000000;
# }
# #T_23acc_row6_col9 {
#   background-color: #5ec962;
#   color: #000000;
# }
# #T_23acc_row6_col10 {
#   background-color: #eae51a;
#   color: #000000;
# }
# #T_23acc_row7_col6 {
#   background-color: #481668;
#   color: #f1f1f1;
# }
# #T_23acc_row7_col7 {
#   background-color: #23898e;
#   color: #f1f1f1;
# }
# #T_23acc_row7_col8 {
#   background-color: #d2e21b;
#   color: #000000;
# }
# #T_23acc_row7_col10 {
#   background-color: #b8de29;
#   color: #000000;
# }
# #T_23acc_row8_col7 {
#   background-color: #482677;
#   color: #f1f1f1;
# }
# #T_23acc_row8_col8 {
#   background-color: #27ad81;
#   color: #f1f1f1;
# }
# #T_23acc_row9_col4, #T_23acc_row9_col7, #T_23acc_row10_col8 {
#   background-color: #450559;
#   color: #f1f1f1;
# }
# #T_23acc_row9_col6 {
#   background-color: #470e61;
#   color: #f1f1f1;
# }
# #T_23acc_row9_col8 {
#   background-color: #471365;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_23acc">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_23acc_level0_col0" class="col_heading level0 col0" >apprentice</th>
#       <th id="T_23acc_level0_col1" class="col_heading level0 col1" >seaman</th>
#       <th id="T_23acc_level0_col2" class="col_heading level0 col2" >capt's servant</th>
#       <th id="T_23acc_level0_col3" class="col_heading level0 col3" >midshipman</th>
#       <th id="T_23acc_level0_col4" class="col_heading level0 col4" >6th mate</th>
#       <th id="T_23acc_level0_col5" class="col_heading level0 col5" >5th mate</th>
#       <th id="T_23acc_level0_col6" class="col_heading level0 col6" >4th mate</th>
#       <th id="T_23acc_level0_col7" class="col_heading level0 col7" >3rd mate</th>
#       <th id="T_23acc_level0_col8" class="col_heading level0 col8" >2nd mate</th>
#       <th id="T_23acc_level0_col9" class="col_heading level0 col9" >1st mate</th>
#       <th id="T_23acc_level0_col10" class="col_heading level0 col10" >capt</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_23acc_level0_row0" class="row_heading level0 row0" >apprentice</th>
#       <td id="T_23acc_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_23acc_row0_col1" class="data row0 col1" >0</td>
#       <td id="T_23acc_row0_col2" class="data row0 col2" >0</td>
#       <td id="T_23acc_row0_col3" class="data row0 col3" >1</td>
#       <td id="T_23acc_row0_col4" class="data row0 col4" >1</td>
#       <td id="T_23acc_row0_col5" class="data row0 col5" >2</td>
#       <td id="T_23acc_row0_col6" class="data row0 col6" >28</td>
#       <td id="T_23acc_row0_col7" class="data row0 col7" >41</td>
#       <td id="T_23acc_row0_col8" class="data row0 col8" >37</td>
#       <td id="T_23acc_row0_col9" class="data row0 col9" >45</td>
#       <td id="T_23acc_row0_col10" class="data row0 col10" >47</td>
#     </tr>
#     <tr>
#       <th id="T_23acc_level0_row1" class="row_heading level0 row1" >seaman</th>
#       <td id="T_23acc_row1_col0" class="data row1 col0" >1</td>
#       <td id="T_23acc_row1_col1" class="data row1 col1" >2</td>
#       <td id="T_23acc_row1_col2" class="data row1 col2" >0</td>
#       <td id="T_23acc_row1_col3" class="data row1 col3" >6</td>
#       <td id="T_23acc_row1_col4" class="data row1 col4" >5</td>
#       <td id="T_23acc_row1_col5" class="data row1 col5" >7</td>
#       <td id="T_23acc_row1_col6" class="data row1 col6" >108</td>
#       <td id="T_23acc_row1_col7" class="data row1 col7" >109</td>
#       <td id="T_23acc_row1_col8" class="data row1 col8" >124</td>
#       <td id="T_23acc_row1_col9" class="data row1 col9" >130</td>
#       <td id="T_23acc_row1_col10" class="data row1 col10" >174</td>
#     </tr>
#     <tr>
#       <th id="T_23acc_level0_row2" class="row_heading level0 row2" >capt's servant</th>
#       <td

# %% [markdown]
# And again for all career movements.

# %%
careers_dict = {}
for first_rank in ranks_ordered_list:
    careers_dict[first_rank] = {}
    for second_rank in ranks_ordered_list:
        careers_dict[first_rank][second_rank] = 0
for person in people_with_jobs:
    rank_list = jobs_df.loc[jobs_df["person_id"] == person]["rank"].tolist()
    if len(rank_list) > 1:
        for move in range(len(rank_list) - 1):
            first_rank = rank_list[move]
            last_rank = rank_list[move + 1]
            careers_dict[first_rank][last_rank] += 1
with open("./jobs/careers_edges.csv", "w") as file:
    file.write("Source;Target;Weight;Direction\n")
    for first_rank in careers_dict:
        for second_rank in careers_dict[first_rank]:
            if not careers_dict[first_rank][second_rank] == 0:
                first_rank_id = rank_id_dict[first_rank]
                second_rank_id = rank_id_dict[second_rank]
                file.write(str(first_rank_id) + ";" + str(second_rank_id) + ";" + str(careers_dict[first_rank][second_rank]) + ";")
                if second_rank_id > first_rank_id:
                    file.write("promotion\n")
                elif second_rank_id == first_rank_id:
                    file.write("unchanged\n")
                else:
                    file.write("demotion\n")
careers_df = pd.DataFrame.from_dict(careers_dict, orient = "index")

# %%
careers_detail_df = careers_df.drop(columns = {"purser", "surgeon's mate", "surgeon", "master", "passenger", "boatswain", "coxswain", "lieutenant", "quarter master"},
                                          index = {"purser", "surgeon's mate", "surgeon", "master", "passenger", "boatswain", "coxswain", "lieutenant", "quarter master"})

careers_styled_df = get_od_matrix(careers_detail_df, "careers")
careers_styled_df
# Out:
# C:\Users\lorga\AppData\Local\Temp\ipykernel_7272\2787265348.py:10: FutureWarning: this method is deprecated in favour of `Styler.to_html()`
#   file.write(styled_df.render())
# <style type="text/css">
# #T_2866b table {
#   font-family: Helvetica;
# }
# #T_2866b td.data {
#   font-family: Helvetica;
#   border: none;
# }
# #T_2866b th.col_heading {
#   font-family: Helvetica;
# }
# #T_2866b th.row_heading {
#   font-family: Helvetica;
# }
# #T_2866b_row0_col0, #T_2866b_row1_col1, #T_2866b_row2_col3, #T_2866b_row3_col3, #T_2866b_row4_col4, #T_2866b_row5_col5, #T_2866b_row5_col6, #T_2866b_row6_col7, #T_2866b_row7_col8, #T_2866b_row8_col8, #T_2866b_row9_col9, #T_2866b_row10_col10 {
#   background-color: #fde725;
#   color: #000000;
# }
# #T_2866b_row0_col1 {
#   background-color: #1f968b;
#   color: #f1f1f1;
# }
# #T_2866b_row0_col2, #T_2866b_row2_col7, #T_2866b_row4_col10, #T_2866b_row5_col1, #T_2866b_row5_col10 {
#   background-color: #46075a;
#   color: #f1f1f1;
# }
# #T_2866b_row0_col3 {
#   background-color: #2a788e;
#   color: #f1f1f1;
# }
# #T_2866b_row0_col4, #T_2866b_row0_col6, #T_2866b_row1_col7, #T_2866b_row9_col8 {
#   background-color: #481668;
#   color: #f1f1f1;
# }
# #T_2866b_row0_col5, #T_2866b_row1_col4 {
#   background-color: #482173;
#   color: #f1f1f1;
# }
# #T_2866b_row0_col7, #T_2866b_row4_col9, #T_2866b_row6_col5, #T_2866b_row8_col6 {
#   background-color: #471063;
#   color: #f1f1f1;
# }
# #T_2866b_row0_col8 {
#   background-color: #365d8d;
#   color: #f1f1f1;
# }
# #T_2866b_row0_col9 {
#   background-color: #46327e;
#   color: #f1f1f1;
# }
# #T_2866b_row0_col10, #T_2866b_row1_col0, #T_2866b_row1_col10, #T_2866b_row2_col0, #T_2866b_row2_col10, #T_2866b_row3_col0, #T_2866b_row3_col10, #T_2866b_row4_col0, #T_2866b_row4_col2, #T_2866b_row5_col0, #T_2866b_row5_col2, #T_2866b_row6_col0, #T_2866b_row6_col1, #T_2866b_row6_col2, #T_2866b_row7_col0, #T_2866b_row7_col1, #T_2866b_row7_col2, #T_2866b_row8_col0, #T_2866b_row8_col2, #T_2866b_row9_col0, #T_2866b_row9_col1, #T_2866b_row9_col2, #T_2866b_row9_col3, #T_2866b_row9_col4, #T_2866b_row10_col0, #T_2866b_row10_col1, #T_2866b_row10_col2, #T_2866b_row10_col3, #T_2866b_row10_col4, #T_2866b_row10_col5, #T_2866b_row10_col6, #T_2866b_row10_col7, #T_2866b_row10_col8 {
#   background-color: #440154;
#   color: #f1f1f1;
# }
# #T_2866b_row1_col2, #T_2866b_row3_col9, #T_2866b_row4_col1, #T_2866b_row7_col5 {
#   background-color: #450559;
#   color: #f1f1f1;
# }
# #T_2866b_row1_col3 {
#   background-color: #1fa187;
#   color: #f1f1f1;
# }
# #T_2866b_row1_col5 {
#   background-color: #46337f;
#   color: #f1f1f1;
# }
# #T_2866b_row1_col6, #T_2866b_row4_col8 {
#   background-color: #472e7c;
#   color: #f1f1f1;
# }
# #T_2866b_row1_col8 {
#   background-color: #482878;
#   color: #f1f1f1;
# }
# #T_2866b_row1_col9, #T_2866b_row5_col4, #T_2866b_row8_col5, #T_2866b_row9_col7 {
#   background-color: #46085c;
#   color: #f1f1f1;
# }
# #T_2866b_row2_col1, #T_2866b_row3_col5 {
#   background-color: #32658e;
#   color: #f1f1f1;
# }
# #T_2866b_row2_col2 {
#   background-color: #73d056;
#   color: #000000;
# }
# #T_2866b_row2_col4 {
#   background-color: #3e4a89;
#   color: #f1f1f1;
# }
# #T_2866b_row2_col5 {
#   background-color: #3b528b;
#   color: #f1f1f1;
# }
# #T_2866b_row2_col6, #T_2866b_row2_col8, #T_2866b_row7_col10 {
#   background-color: #471365;
#   color: #f1f1f1;
# }
# #T_2866b_row2_col9, #T_2866b_row3_col2, #T_2866b_row7_col3, #T_2866b_row8_col1, #T_2866b_row10_col9 {
#   background-color: #450457;
#   color: #f1f1f1;
# }
# #T_2866b_row3_col1 {
#   background-color: #481769;
#   color: #f1f1f1;
# }
# #T_2866b_row3_col4 {
#   background-color: #3f4788;
#   color: #f1f1f1;
# }
# #T_2866b_row3_col6 {
#   background-color: #3a538b;
#   color: #f1f1f1;
# }
# #T_2866b_row3_col7 {
#   background-color: #482071;
#   color: #f1f1f1;
# }
# #T_2866b_row3_col8 {
#   background-color: #481b6d;
#   color: #f1f1f1;
# }
# #T_2866b_row4_col3, #T_2866b_row5_col3, #T_2866b_row6_col3, #T_2866b_row6_col4, #T_2866b_row7_col4, #T_2866b_row8_col4, #T_2866b_row9_col5, #T_2866b_row9_col6 {
#   background-color: #440256;
#   color: #f1f1f1;
# }
# #T_2866b_row4_col5 {
#   background-color: #23888e;
#   color: #f1f1f1;
# }
# #T_2866b_row4_col6 {
#   background-color: #63cb5f;
#   color: #000000;
# }
# #T_2866b_row4_col7 {
#   background-color: #3b518b;
#   color: #f1f1f1;
# }
# #T_2866b_row5_col7 {
#   background-color: #3aba76;
#   color: #f1f1f1;
# }
# #T_2866b_row5_col8 {
#   background-color: #3e4989;
#   color: #f1f1f1;
# }
# #T_2866b_row5_col9, #T_2866b_row8_col7 {
#   background-color: #48186a;
#   color: #f1f1f1;
# }
# #T_2866b_row6_col6 {
#   background-color: #f8e621;
#   color: #000000;
# }
# #T_2866b_row6_col8 {
#   background-color: #24878e;
#   color: #f1f1f1;
# }
# #T_2866b_row6_col9 {
#   background-color: #481f70;
#   color: #f1f1f1;
# }
# #T_2866b_row6_col10, #T_2866b_row8_col3 {
#   background-color: #460a5d;
#   color: #f1f1f1;
# }
# #T_2866b_row7_col6 {
#   background-color: #470d60;
#   color: #f1f1f1;
# }
# #T_2866b_row7_col7 {
#   background-color: #fbe723;
#   color: #000000;
# }
# #T_2866b_row7_col9 {
#   background-color: #375a8c;
#   color: #f1f1f1;
# }
# #T_2866b_row8_col9 {
#   background-color: #21a585;
#   color: #f1f1f1;
# }
# #T_2866b_row8_col10 {
#   background-color: #443a83;
#   color: #f1f1f1;
# }
# #T_2866b_row9_col10 {
#   background-color: #39568c;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_2866b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2866b_level0_col0" class="col_heading level0 col0" >apprentice</th>
#       <th id="T_2866b_level0_col1" class="col_heading level0 col1" >seaman</th>
#       <th id="T_2866b_level0_col2" class="col_heading level0 col2" >capt's servant</th>
#       <th id="T_2866b_level0_col3" class="col_heading level0 col3" >midshipman</th>
#       <th id="T_2866b_level0_col4" class="col_heading level0 col4" >6th mate</th>
#       <th id="T_2866b_level0_col5" class="col_heading level0 col5" >5th mate</th>
#       <th id="T_2866b_level0_col6" class="col_heading level0 col6" >4th mate</th>
#       <th id="T_2866b_level0_col7" class="col_heading level0 col7" >3rd mate</th>
#       <th id="T_2866b_level0_col8" class="col_heading level0 col8" >2nd mate</th>
#       <th id="T_2866b_level0_col9" class="col_heading level0 col9" >1st mate</th>
#       <th id="T_2866b_level0_col10" class="col_heading level0 col10" >capt</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2866b_level0_row0" class="row_heading level0 row0" >apprentice</th>
#       <td id="T_2866b_row0_col0" class="data row0 col0" >120</td>
#       <td id="T_2866b_row0_col1" class="data row0 col1" >63</td>
#       <td id="T_2866b_row0_col2" class="data row0 col2" >2</td>
#       <td id="T_2866b_row0_col3" class="data row0 col3" >48</td>
#       <td id="T_2866b_row0_col4" class="data row0 col4" >7</td>
#       <td id="T_2866b_row0_col5" class="data row0 col5" >11</td>
#       <td id="T_2866b_row0_col6" class="data row0 col6" >7</td>
#       <td id="T_2866b_row0_col7" class="data row0 col7" >5</td>
#       <td id="T_2866b_row0_col8" class="data row0 col8" >35</td>
#       <td id="T_2866b_row0_col9" class="data row0 col9" >17</td>
#       <td id="T_2866b_row0_col10" class="data row0 col10" >0</td>
#     </tr>
#     <tr>
#       <th id="T_2866b_level0_row1" class="row_heading level0 row1" >seaman</th>
#       <td id="T_2866b_row1_col0" class="data row1 col0" >4</td>
#       <td id="T_2866b_row1_col1" class="data row1 col1" >762</td>
#       <td id="T_2866b_row1_col2" class="data row1 col2" >12</td>
#       <td id="T_2866b_row1_col3" class="data row1 col3" >436</td>
#       <td id="T_2866b_row1_col4" class="data row1 col4" >73</td>
#       <td id="T_2866b_row1_col5" class="data row1 col5" >113</td>
#       <td id="T_2866b_row1_col6" class="data row1 col6" >100</td>
#       <td id="T_2866b_row1_col7" class="data row1 col7" >44</td>
#       <td id="T_2866b_row1_col8" class="data row1 col8" >86</td>
#       <td id="T_2866b_row1_col9" class="data row1 col9" >17</td>
#       <td id="T_2866b_row1_col10" class="data row1 col10" >2</td>
#     </tr>
#     <tr>
#       <th id="T_2866b_level0_row2" class="row_heading level0 row2" >capt's servant</th>
#       <td id="T_2866b_row2_col0" class="data row2 col0" >0</td>
#       <td id="T_2866b_row2_col1" class="data row2 col1" >33</td>
#       <td id="T_2866b_row2_col2" class="data row2 col2" >81</td>
#       <td id="T_2866b_row2_col3" class="data row2 col3" >103</td>
#       <td id="T_2866b_row2_col4" class="data row2 col4" >23</td>
#       <td id="T_2866b_row2_col

# %% [markdown]
# ## The role of the father's occupation

# %% [markdown]
# How many fathers' jobs do we have data on and how many unique jobs are there?

# %%
people_father_job_df = people_df.loc[people_df["father_job"].notna()]
len(people_father_job_df.index), people_df["father_job"].nunique()
# Out:
# (162, 65)

# %%
people_df["father_job"].unique()
# Out:
# array([nan, 'baillie', 'oilman', 'gent', 'plumber', 'hatter', 'Maj-Gen',
#        'mariner', 'vicar', 'Esq', 'sailmaker', 'Surgeon',
#        'Custom House agent', 'linendraper', 'cooper', 'minister',
#        'hop merchant', 'grocer', 'shipmaster', 'wine merchant',
#        'labourer', 'Capt', 'attorney', 'British Consul at Madeira',
#        'sumgeom', 'silk manufacturer', 'rector', 'Bart', 'biscuit baker',
#        'victualler', 'coal merchant', 'dyer', 'solicitor', 'shipbuilder',
#        'Jamaica)', 'shipwright', 'brandy merchant', 'schoolmaster',
#        'ropemaker', "banker's clerk", 'waterman', 'bricklayer',
#        'merchant', 'vieat', 'banker', 'doctor', 'lecturer', 'farmer',
#        'menelnams', '4 merchant', 'warehouseman', 'builder', 'tmexchemt',
#        'rector of Calne', 'gardener', 'mercer', 'tinier', 'jun',
#        'iron merchant', 'brewer', 'surgeon',
#        'midshipman NORTHAMPTON (2) 1802/3', 'Proctor in Doctors Commons',
#        'maltster', 'timber merchant', 'curate'], dtype=object)

# %% [markdown]
# What are the most frequent fathers' jobs?

# %%
father_job_df = people_df.loc[people_df["father_job"].notna()]
father_job_df.value_counts("father_job")[:10]
# Out:
# father_job
# Esq           44
# gent          18
# mariner       12
# merchant       9
# surgeon        4
# vicar          3
# rector         3
# farmer         3
# shipwright     3
# Capt           3
# dtype: int64

# %% [markdown]
# Categorise fathers' jobs

# %%
father_category_dict = {
"sea":                          ["mariner", "shipmaster", "capt"],
"labourers":                    ["labourer", "plumber", "builder", "waterman", 
                                "oilman", "cooper", "bricklayer", "warehouseman",
                                "gardener", "farmer"],
"artisans":
                               ["linendraper", "ropemaker", "hatter", "tinier", "dyer", "farmer", "maltster",
                                "sailmaker", "brewer", "biscuit baker", "banker's clerk", "shipwright"],
"merchants":
                               ["timber merchant", "hop merchant", "iron merchant", "coal merchant", "victualler",
                                "wine merchant", "brandy merchant", "grocer", "merchant", "silk manufacturer"],
"educated":
                               ["schoolmaster", "rector", "curate", "lecturer", "doctor", "minister",
                               "surgeon", "proctor in doctors commons", "custom house agent", "baillie", "solicitor",
                               "vicar", "attorney", "banker", "maj-gen"],
"gentry":
                               ["gent", "esq"]
}

# %% [markdown]
# Count categories

# %%
category_count_dict = {}
for category in father_category_dict:
    category_count_dict[category] = 0
for father_job in people_father_job_df["father_job"].tolist():
    for category in father_category_dict:
        if father_job.lower() in father_category_dict[category]:
            category_count_dict[category] += 1
category_count_df = pd.DataFrame.from_dict(category_count_dict, orient = "index")
category_count_df = category_count_df.reset_index().rename(columns = {"index": "category", 0: "count"})
category_count_df
# Out:
#     category  count
# 0        sea     17
# 1  labourers     13
# 2   artisans     16
# 3  merchants     18
# 4   educated     25
# 5     gentry     62

# %% [markdown]
# Did people with fathers in higher positions start in a higher position themselves?

# %%
people_jobs_df = pd.merge(people_father_job_df, jobs_df,
                         how = "left",
                         on = "person_id")
father_first_job_dict = {}
father_last_job_dict = {}
people_with_fathers_and_jobs = list(set(people_jobs_df.loc[people_jobs_df["father_job"].notna()]["person_id"].tolist()))
for category in father_category_dict.keys():
    father_first_job_dict[category] = {}
    father_last_job_dict[category] = {}
    for job in ranks_ordered_list:
        father_first_job_dict[category][job] = 0
        father_last_job_dict[category][job] = 0
for person in people_with_fathers_and_jobs: 
    first_job = people_jobs_df.loc[people_jobs_df["person_id"] == person]["rank"].tolist()[0]
    last_job = people_jobs_df.loc[people_jobs_df["person_id"] == person]["rank"].tolist()[-1]
    father_job = people_jobs_df.loc[people_jobs_df["person_id"] == person]["father_job"].tolist()[0].lower()
    if first_job in ranks_ordered_list:
        for category in father_category_dict.keys():
            if father_job in father_category_dict[category]:
                father_category = category
        father_first_job_dict[father_category][first_job] += 1
    if last_job in ranks_ordered_list:
        for category in father_category_dict.keys():
            if father_job in father_category_dict[category]:
                father_category = category
        father_last_job_dict[father_category][last_job] += 1
father_first_job_count_df = pd.DataFrame.from_dict(father_first_job_dict, orient = "index")
father_last_job_count_df = pd.DataFrame.from_dict(father_last_job_dict, orient = "index")

# %%
father_first_job_count_styled_df = get_od_matrix(father_first_job_count_df, "father_first_job")
father_first_job_count_styled_df
# Out:
# C:\Users\lorga\AppData\Local\Temp\ipykernel_7272\2787265348.py:10: FutureWarning: this method is deprecated in favour of `Styler.to_html()`
#   file.write(styled_df.render())
# <style type="text/css">
# #T_392e2 table {
#   font-family: Helvetica;
# }
# #T_392e2 td.data {
#   font-family: Helvetica;
#   border: none;
# }
# #T_392e2 th.col_heading {
#   font-family: Helvetica;
# }
# #T_392e2 th.row_heading {
#   font-family: Helvetica;
# }
# #T_392e2_row0_col0, #T_392e2_row0_col1, #T_392e2_row0_col4, #T_392e2_row0_col6, #T_392e2_row0_col7, #T_392e2_row0_col8, #T_392e2_row0_col11, #T_392e2_row0_col12, #T_392e2_row0_col13, #T_392e2_row0_col15, #T_392e2_row0_col16, #T_392e2_row0_col17, #T_392e2_row0_col18, #T_392e2_row0_col19, #T_392e2_row1_col0, #T_392e2_row1_col1, #T_392e2_row1_col3, #T_392e2_row1_col4, #T_392e2_row1_col6, #T_392e2_row1_col7, #T_392e2_row1_col8, #T_392e2_row1_col9, #T_392e2_row1_col11, #T_392e2_row1_col13, #T_392e2_row1_col14, #T_392e2_row1_col15, #T_392e2_row1_col16, #T_392e2_row1_col17, #T_392e2_row1_col18, #T_392e2_row1_col19, #T_392e2_row2_col4, #T_392e2_row2_col6, #T_392e2_row2_col7, #T_392e2_row2_col8, #T_392e2_row2_col11, #T_392e2_row2_col12, #T_392e2_row2_col13, #T_392e2_row2_col14, #T_392e2_row2_col16, #T_392e2_row2_col17, #T_392e2_row2_col18, #T_392e2_row2_col19, #T_392e2_row3_col4, #T_392e2_row3_col6, #T_392e2_row3_col7, #T_392e2_row3_col8, #T_392e2_row3_col11, #T_392e2_row3_col12, #T_392e2_row3_col13, #T_392e2_row3_col14, #T_392e2_row3_col15, #T_392e2_row3_col16, #T_392e2_row3_col17, #T_392e2_row3_col18, #T_392e2_row3_col19, #T_392e2_row4_col1, #T_392e2_row4_col4, #T_392e2_row4_col6, #T_392e2_row4_col7, #T_392e2_row4_col8, #T_392e2_row4_col11, #T_392e2_row4_col13, #T_392e2_row4_col15, #T_392e2_row4_col16, #T_392e2_row4_col17, #T_392e2_row4_col18, #T_392e2_row4_col19, #T_392e2_row5_col0, #T_392e2_row5_col4, #T_392e2_row5_col6, #T_392e2_row5_col7, #T_392e2_row5_col8, #T_392e2_row5_col11, #T_392e2_row5_col12, #T_392e2_row5_col16, #T_392e2_row5_col17, #T_392e2_row5_col18, #T_392e2_row5_col19 {
#   background-color: #440154;
#   color: #f1f1f1;
# }
# #T_392e2_row0_col2, #T_392e2_row0_col5, #T_392e2_row1_col2, #T_392e2_row2_col2, #T_392e2_row2_col5, #T_392e2_row3_col5, #T_392e2_row4_col5, #T_392e2_row5_col5 {
#   background-color: #fde725;
#   color: #000000;
# }
# #T_392e2_row0_col3, #T_392e2_row0_col10 {
#   background-color: #2a788e;
#   color: #f1f1f1;
# }
# #T_392e2_row0_col9, #T_392e2_row0_col14 {
#   background-color: #414487;
#   color: #f1f1f1;
# }
# #T_392e2_row1_col5, #T_392e2_row1_col10 {
#   background-color: #5ec962;
#   color: #000000;
# }
# #T_392e2_row1_col12 {
#   background-color: #3b528b;
#   color: #f1f1f1;
# }
# #T_392e2_row2_col0, #T_392e2_row2_col1, #T_392e2_row2_col3, #T_392e2_row2_col10, #T_392e2_row2_col15 {
#   background-color: #443983;
#   color: #f1f1f1;
# }
# #T_392e2_row2_col9 {
#   background-color: #31688e;
#   color: #f1f1f1;
# }
# #T_392e2_row3_col0, #T_392e2_row3_col1, #T_392e2_row3_col2, #T_392e2_row3_col3, #T_392e2_row3_col10, #T_392e2_row5_col3, #T_392e2_row5_col9 {
#   background-color: #482173;
#   color: #f1f1f1;
# }
# #T_392e2_row3_col9 {
#   background-color: #25858e;
#   color: #f1f1f1;
# }
# #T_392e2_row4_col0, #T_392e2_row4_col9, #T_392e2_row4_col12, #T_392e2_row4_col14 {
#   background-color: #481c6e;
#   color: #f1f1f1;
# }
# #T_392e2_row4_col2 {
#   background-color: #453581;
#   color: #f1f1f1;
# }
# #T_392e2_row4_col3, #T_392e2_row5_col2 {
#   background-color: #3d4d8a;
#   color: #f1f1f1;
# }
# #T_392e2_row4_col10 {
#   background-color: #2b748e;
#   color: #f1f1f1;
# }
# #T_392e2_row5_col1, #T_392e2_row5_col13, #T_392e2_row5_col14, #T_392e2_row5_col15 {
#   background-color: #46085c;
#   color: #f1f1f1;
# }
# #T_392e2_row5_col10 {
#   background-color: #471164;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_392e2">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_392e2_level0_col0" class="col_heading level0 col0" >apprentice</th>
#       <th id="T_392e2_level0_col1" class="col_heading level0 col1" >purser</th>
#       <th id="T_392e2_level0_col2" class="col_heading level0 col2" >seaman</th>
#       <th id="T_392e2_level0_col3" class="col_heading level0 col3" >capt's servant</th>
#       <th id="T_392e2_level0_col4" class="col_heading level0 col4" >quarter master</th>
#       <th id="T_392e2_level0_col5" class="col_heading level0 col5" >midshipman</th>
#       <th id="T_392e2_level0_col6" class="col_heading level0 col6" >coxswain</th>
#       <th id="T_392e2_level0_col7" class="col_heading level0 col7" >lieutenant</th>
#       <th id="T_392e2_level0_col8" class="col_heading level0 col8" >boatswain</th>
#       <th id="T_392e2_level0_col9" class="col_heading level0 col9" >6th mate</th>
#       <th id="T_392e2_level0_col10" class="col_heading level0 col10" >5th mate</th>
#       <th id="T_392e2_level0_col11" class="col_heading level0 col11" >4th mate</th>
#       <th id="T_392e2_level0_col12" class="col_heading level0 col12" >surgeon's mate</th>
#       <th id="T_392e2_level0_col13" class="col_heading level0 col13" >surgeon</th>
#       <th id="T_392e2_level0_col14" class="col_heading level0 col14" >3rd mate</th>
#       <th id="T_392e2_level0_col15" class="col_heading level0 col15" >2nd mate</th>
#       <th id="T_392e2_level0_col16" class="col_heading level0 col16" >1st mate</th>
#       <th id="T_392e2_level0_col17" class="col_heading level0 col17" >master</th>
#       <th id="T_392e2_level0_col18" class="col_heading level0 col18" >capt</th>
#       <th id="T_392e2_level0_col19" class="col_heading level0 col19" >passenger</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_392e2_level0_row0" class="row_heading level0 row0" >sea</th>
#       <td id="T_392e2_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_392e2_row0_col1" class="data row0 col1" >0</td>
#       <td id="T_392e2_row0_col2" class="data row0 col2" >5</td>
#       <td id="T_392e2_row0_col3" class="data row0 col3" >2</td>
#       <td id="T_392e2_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_392e2_row0_col5" class="data row0 col5" >5</td>
#       <td id="T_392e2_row0_col6" class="data row0 col6" >0</td>
#       <td id="T_392e2_row0_col7" class="data row0 col7" >0</td>
#       <td id="T_392e2_row0_col8" class="data row0 col8" >0</td>
#       <td id="T_392e2_row0_col9" class="data row0 col9" >1</td>
#       <td id="T_392e2_row0_col10" class="data row0 col10" >2</td>
#       <td id="T_392e2_row0_col11" class="data row0 col11" >0</td>
#       <td id="T_392e2_row0_col12" class="data row0 col12" >0</td>
#       <td id="T_392e2_row0_col13" class="data row0 col13" >0</td>
#       <td id="T_392e2_row0_col14" class="data row0 col14" >1</td>
#       <td id="T_392e2_row0_col15" class="data row0 col15" >0</td>
#       <td id="T_392e2_row0_col16" class="data row0 col16" >0</td>
#       <td id="T_392e2_row0_col17" class="data row0 col17" >0</td>
#       <td id="T_392e2_row0_col18" class="data row0 col18" >0</td>
#       <td id="T_392e2_row0_col19" class="data row0 col19" >0</td>
#     </tr>
#     <tr>
#       <th id="T_392e2_level0_row1" class="row_heading level0 row1" >labourers</th>
#       <td id="T_392e2_row1_col0" class="data row1 col0" >0</td>
#       <td id="T_392e2_row1_col1" class="data row1 col1" >0</td>
#       <td id="T_392e2_row1_col2" class="data row1 col2" >4</td>
#       <td id="T_392e2_row1_col3" class="data row1 col3" >0</td>
#       <td id="T_392e2_row1_col4" class="data row1 col4" >0</td>
#       <td id="T_392e2_row1_col5" class="data row1 col5" >3</td>
#       <td id="T_392e2_row1_col6" class="data row1 col6" >0</td>
#       <td id="T_392e2_row1_col7" class="data row1 col7" >0</td>
#       <td id="T_392e2_row1_col8" class="data row1 col8" >0</td>
#       <td id="T_392e2_row1_col9" class="data row1 col9" >0</td>
#       <td id="T_392e2_row1_col10" class="data row1 col10" >3</td>
#       <td id="T_392e2_row1_col11" class="data row1 col11" >0</td>
#       <td id="T_392e2_row1_col12" class="data row1 col12" >1</td>
#       <td id="T_392e2_row1_col13" class="data row1 col13" >0</td>
#       <td id="T_392e2_row1_col14" class="data row1 col14" >0</td>
#       <td id="T_392e2_row1_col15" class="data row1 col15" >0</td>
#       <td id="T_392e2_row1_col16" class="data row1 col16" >0</td>
#       <td id="T_392e2_row1_col17" class="data row1 col17" >0</td>
#       <td id="T_392e2_row1_col18" class="data

# %% [markdown]
# Did they end in a higher position?

# %%
father_last_job_count_styled_df = get_od_matrix(father_last_job_count_df, "father_last_job")
father_last_job_count_styled_df
# Out:
# C:\Users\lorga\AppData\Local\Temp\ipykernel_7272\2787265348.py:10: FutureWarning: this method is deprecated in favour of `Styler.to_html()`
#   file.write(styled_df.render())
# <style type="text/css">
# #T_abeec table {
#   font-family: Helvetica;
# }
# #T_abeec td.data {
#   font-family: Helvetica;
#   border: none;
# }
# #T_abeec th.col_heading {
#   font-family: Helvetica;
# }
# #T_abeec th.row_heading {
#   font-family: Helvetica;
# }
# #T_abeec_row0_col0, #T_abeec_row0_col1, #T_abeec_row0_col2, #T_abeec_row0_col3, #T_abeec_row0_col4, #T_abeec_row0_col5, #T_abeec_row0_col6, #T_abeec_row0_col7, #T_abeec_row0_col8, #T_abeec_row0_col9, #T_abeec_row0_col12, #T_abeec_row0_col13, #T_abeec_row0_col17, #T_abeec_row0_col19, #T_abeec_row1_col0, #T_abeec_row1_col2, #T_abeec_row1_col3, #T_abeec_row1_col4, #T_abeec_row1_col5, #T_abeec_row1_col6, #T_abeec_row1_col7, #T_abeec_row1_col8, #T_abeec_row1_col9, #T_abeec_row1_col10, #T_abeec_row1_col12, #T_abeec_row1_col17, #T_abeec_row1_col19, #T_abeec_row2_col0, #T_abeec_row2_col2, #T_abeec_row2_col3, #T_abeec_row2_col4, #T_abeec_row2_col5, #T_abeec_row2_col6, #T_abeec_row2_col7, #T_abeec_row2_col8, #T_abeec_row2_col12, #T_abeec_row2_col13, #T_abeec_row2_col17, #T_abeec_row2_col19, #T_abeec_row3_col0, #T_abeec_row3_col2, #T_abeec_row3_col3, #T_abeec_row3_col4, #T_abeec_row3_col5, #T_abeec_row3_col6, #T_abeec_row3_col7, #T_abeec_row3_col8, #T_abeec_row3_col10, #T_abeec_row3_col12, #T_abeec_row3_col13, #T_abeec_row3_col17, #T_abeec_row3_col19, #T_abeec_row4_col0, #T_abeec_row4_col1, #T_abeec_row4_col2, #T_abeec_row4_col3, #T_abeec_row4_col4, #T_abeec_row4_col6, #T_abeec_row4_col7, #T_abeec_row4_col8, #T_abeec_row4_col12, #T_abeec_row4_col17, #T_abeec_row4_col19, #T_abeec_row5_col0, #T_abeec_row5_col2, #T_abeec_row5_col3, #T_abeec_row5_col4, #T_abeec_row5_col6, #T_abeec_row5_col7, #T_abeec_row5_col8, #T_abeec_row5_col12, #T_abeec_row5_col17, #T_abeec_row5_col19 {
#   background-color: #440154;
#   color: #f1f1f1;
# }
# #T_abeec_row0_col10, #T_abeec_row0_col15 {
#   background-color: #414487;
#   color: #f1f1f1;
# }
# #T_abeec_row0_col11 {
#   background-color: #7ad151;
#   color: #000000;
# }
# #T_abeec_row0_col14 {
#   background-color: #2a788e;
#   color: #f1f1f1;
# }
# #T_abeec_row0_col16 {
#   background-color: #22a884;
#   color: #f1f1f1;
# }
# #T_abeec_row0_col18, #T_abeec_row1_col15, #T_abeec_row2_col15, #T_abeec_row2_col16, #T_abeec_row3_col18, #T_abeec_row4_col10, #T_abeec_row5_col15 {
#   background-color: #fde725;
#   color: #000000;
# }
# #T_abeec_row1_col1, #T_abeec_row1_col11, #T_abeec_row1_col13, #T_abeec_row1_col14, #T_abeec_row3_col1, #T_abeec_row3_col16 {
#   background-color: #31688e;
#   color: #f1f1f1;
# }
# #T_abeec_row1_col16, #T_abeec_row1_col18, #T_abeec_row3_col11 {
#   background-color: #35b779;
#   color: #f1f1f1;
# }
# #T_abeec_row2_col1, #T_abeec_row2_col10, #T_abeec_row2_col11, #T_abeec_row5_col11 {
#   background-color: #3b528b;
#   color: #f1f1f1;
# }
# #T_abeec_row2_col9, #T_abeec_row3_col14, #T_abeec_row3_col15 {
#   background-color: #21918c;
#   color: #f1f1f1;
# }
# #T_abeec_row2_col14, #T_abeec_row2_col18, #T_abeec_row5_col14 {
#   background-color: #5ec962;
#   color: #000000;
# }
# #T_abeec_row3_col9 {
#   background-color: #443983;
#   color: #f1f1f1;
# }
# #T_abeec_row4_col5, #T_abeec_row4_col9, #T_abeec_row4_col13 {
#   background-color: #46327e;
#   color: #f1f1f1;
# }
# #T_abeec_row4_col11 {
#   background-color: #277f8e;
#   color: #f1f1f1;
# }
# #T_abeec_row4_col14, #T_abeec_row4_col16 {
#   background-color: #365c8d;
#   color: #f1f1f1;
# }
# #T_abeec_row4_col15 {
#   background-color: #a0da39;
#   color: #000000;
# }
# #T_abeec_row4_col18 {
#   background-color: #1fa187;
#   color: #f1f1f1;
# }
# #T_abeec_row5_col1, #T_abeec_row5_col5 {
#   background-color: #472d7b;
#   color: #f1f1f1;
# }
# #T_abeec_row5_col9 {
#   background-color: #33638d;
#   color: #f1f1f1;
# }
# #T_abeec_row5_col10 {
#   background-color: #26828e;
#   color: #f1f1f1;
# }
# #T_abeec_row5_col13 {
#   background-color: #48186a;
#   color: #f1f1f1;
# }
# #T_abeec_row5_col16, #T_abeec_row5_col18 {
#   background-color: #1fa088;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_abeec">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_abeec_level0_col0" class="col_heading level0 col0" >apprentice</th>
#       <th id="T_abeec_level0_col1" class="col_heading level0 col1" >purser</th>
#       <th id="T_abeec_level0_col2" class="col_heading level0 col2" >seaman</th>
#       <th id="T_abeec_level0_col3" class="col_heading level0 col3" >capt's servant</th>
#       <th id="T_abeec_level0_col4" class="col_heading level0 col4" >quarter master</th>
#       <th id="T_abeec_level0_col5" class="col_heading level0 col5" >midshipman</th>
#       <th id="T_abeec_level0_col6" class="col_heading level0 col6" >coxswain</th>
#       <th id="T_abeec_level0_col7" class="col_heading level0 col7" >lieutenant</th>
#       <th id="T_abeec_level0_col8" class="col_heading level0 col8" >boatswain</th>
#       <th id="T_abeec_level0_col9" class="col_heading level0 col9" >6th mate</th>
#       <th id="T_abeec_level0_col10" class="col_heading level0 col10" >5th mate</th>
#       <th id="T_abeec_level0_col11" class="col_heading level0 col11" >4th mate</th>
#       <th id="T_abeec_level0_col12" class="col_heading level0 col12" >surgeon's mate</th>
#       <th id="T_abeec_level0_col13" class="col_heading level0 col13" >surgeon</th>
#       <th id="T_abeec_level0_col14" class="col_heading level0 col14" >3rd mate</th>
#       <th id="T_abeec_level0_col15" class="col_heading level0 col15" >2nd mate</th>
#       <th id="T_abeec_level0_col16" class="col_heading level0 col16" >1st mate</th>
#       <th id="T_abeec_level0_col17" class="col_heading level0 col17" >master</th>
#       <th id="T_abeec_level0_col18" class="col_heading level0 col18" >capt</th>
#       <th id="T_abeec_level0_col19" class="col_heading level0 col19" >passenger</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_abeec_level0_row0" class="row_heading level0 row0" >sea</th>
#       <td id="T_abeec_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_abeec_row0_col1" class="data row0 col1" >0</td>
#       <td id="T_abeec_row0_col2" class="data row0 col2" >0</td>
#       <td id="T_abeec_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_abeec_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_abeec_row0_col5" class="data row0 col5" >0</td>
#       <td id="T_abeec_row0_col6" class="data row0 col6" >0</td>
#       <td id="T_abeec_row0_col7" class="data row0 col7" >0</td>
#       <td id="T_abeec_row0_col8" class="data row0 col8" >0</td>
#       <td id="T_abeec_row0_col9" class="data row0 col9" >0</td>
#       <td id="T_abeec_row0_col10" class="data row0 col10" >1</td>
#       <td id="T_abeec_row0_col11" class="data row0 col11" >4</td>
#       <td id="T_abeec_row0_col12" class="data row0 col12" >0</td>
#       <td id="T_abeec_row0_col13" class="data row0 col13" >0</td>
#       <td id="T_abeec_row0_col14" class="data row0 col14" >2</td>
#       <td id="T_abeec_row0_col15" class="data row0 col15" >1</td>
#       <td id="T_abeec_row0_col16" class="data row0 col16" >3</td>
#       <td id="T_abeec_row0_col17" class="data row0 col17" >0</td>
#       <td id="T_abeec_row0_col18" class="data row0 col18" >5</td>
#       <td id="T_abeec_row0_col19" class="data row0 col19" >0</td>
#     </tr>
#     <tr>
#       <th id="T_abeec_level0_row1" class="row_heading level0 row1" >labourers</th>
#       <td id="T_abeec_row1_col0" class="data row1 col0" >0</td>
#       <td id="T_abeec_row1_col1" class="data row1 col1" >1</td>
#       <td id="T_abeec_row1_col2" class="data row1 col2" >0</td>
#       <td id="T_abeec_row1_col3" class="data row1 col3" >0</td>
#       <td id="T_abeec_row1_col4" class="data row1 col4" >0</td>
#       <td id="T_abeec_row1_col5" class="data row1 col5" >0</td>
#       <td id="T_abeec_row1_col6" class="data row1 col6" >0</td>
#       <td id="T_abeec_row1_col7" class="data row1 col7" >0</td>
#       <td id="T_abeec_row1_col8" class="data row1 col8" >0</td>
#       <td id="T_abeec_row1_col9" class="data row1 col9" >0</td>
#       <td id="T_abeec_row1_col10" class="data row1 col10" >0</td>
#       <td id="T_abeec_row1_col11" class="data row1 col11" >1</td>
#       <td id="T_abeec_row1_col12" class="data row1 col12" >0</td>
#       <td id="T_abeec_row1_col13" class="data row1 col13" >1</td>
#       <td
